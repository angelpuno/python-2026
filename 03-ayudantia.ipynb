# %% [markdown]
# Ejercicio 1

# %%
import numpy as np

# %%
lenguajes= ["Python", "C++", "Java", "JavaScript", "C#"] 
preferencia = [45, 20, 15, 12, 8] 
print(lenguajes)
preferencia
# Out:
# ['Python', 'C++', 'Java', 'JavaScript', 'C#']
# [45, 20, 15, 12, 8]

# %% [markdown]
# Ejercicio 2

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
plt.bar(lenguajes, preferencia, color=['red', 'green', 'yellow', 'cyan', 'purple'])
plt.title('Preferencia de Lenguajes de programacion', fontsize=12, fontweight='bold')
plt.xlabel('Lenguajes', fontsize=12)
plt.ylabel('Porcentaje de Preferencia', fontsize=12)
plt.show()
