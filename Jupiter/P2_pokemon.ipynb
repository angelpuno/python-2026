# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv("data/Pokemon.csv", index_col="Number")
datos.head(10)
# Out:
#                     Name Type 1  Type 2                    Abilities  HP  Att  \
# Number
# 1              Bulbasaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  45   49
# 2                Ivysaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  60   62
# 3               Venusaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  80   82
# 3          Mega Venusaur  Grass  Poison                ['Thick Fat']  80  100
# 4             Charmander   Fire     NaN     ['Blaze', 'Solar Power']  39   52
# 5             Charmeleon   Fire     NaN     ['Blaze', 'Solar Power']  58   64
# 6              Charizard   Fire  Flying     ['Blaze', 'Solar Power']  78   84
# 6       Mega Charizard Y   Fire  Flying                  ['Drought']  78  104
# 6       Mega Charizard X   Fire  Dragon              ['Tough Claws']  78  130
# 7               Squirtle  Water     NaN     ['Rain Dish', 'Torrent']  44   48
#
#         Def  Spa  Spd  Spe  ...  Against Bug  Against Rock  Against Ghost  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1037 entries, 1 to 389
# Data columns (total 43 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     1037 non-null   str
#  1   Type 1                   1037 non-null   str
#  2   Type 2                   551 non-null    str
#  3   Abilities                1037 non-null   str
#  4   HP                       1037 non-null   int64
#  5   Att                      1037 non-null   int64
#  6   Def                      1037 non-null   int64
#  7   Spa                      1037 non-null   int64
#  8   Spd                      1037 non-null   int64
#  9   Spe                      1037 non-null   int64
#  10  BST                      1037 non-null   int64
#  11  Mean                     1037 non-null   float64
#  12  Standard Deviation       1037 non-null   float64
#  13  Generation               1037 non-null   float64
# ...

# %%
data.isnull().any()
# Out:
# Name                       False
# Type 1                     False
# Type 2                      True
# Abilities                  False
# HP                         False
# Att                        False
# Def                        False
# Spa                        False
# Spd                        False
# Spe                        False
# BST                        False
# Mean                       False
# Standard Deviation         False
# Generation                 False
# Experience type            False
# Experience to level 100    False
# Final Evolution            False
# Catch Rate                 False
# Legendary                  False
# Mega Evolution             False
# Alolan Form                False
# Galarian Form              False
# Against Normal             False
# Against Fire               False
# Against Water              False
# Against Electric           False
# Against Grass              False
# Against Ice                False
# ...

# %%
datos_sin_nulos= datos.dropna().copy()
datos_sin_nulos
# Out:
#                         Name    Type 1   Type 2                    Abilities  \
# Number
# 1                  Bulbasaur     Grass   Poison  ['Chlorophyll', 'Overgrow']
# 2                    Ivysaur     Grass   Poison  ['Chlorophyll', 'Overgrow']
# 3                   Venusaur     Grass   Poison  ['Chlorophyll', 'Overgrow']
# 3              Mega Venusaur     Grass   Poison                ['Thick Fat']
# 6                  Charizard      Fire   Flying     ['Blaze', 'Solar Power']
# ...                      ...       ...      ...                          ...
# 898        Calyrex Ice Rider   Psychic      Ice                   ['As One']
# 898     Calyrex Shadow Rider   Psychic    Ghost                   ['As One']
# 899            Alolan Raichu  Electric  Psychic             ['Surge Surfer']
# 6                  Charizard      Fire   Flying     ['Blaze', 'Solar Power']
# 389                 Torterra     Grass   Ground  ['Overgrow', 'Shell Armor']
#
# ...

# %%
datos.duplicated()
# Out:
# Number
# 1      False
# 2      False
# 3      False
# 3      False
# 4      False
#        ...
# 899     True
# 900     True
# 25      True
# 6       True
# 389     True
# Length: 1037, dtype: bool

# %%
datos_sin_dup= datos.drop_duplicates().copy()
datos_sin_dup
# Out:
#                         Name   Type 1  Type 2                    Abilities  \
# Number
# 1                  Bulbasaur    Grass  Poison  ['Chlorophyll', 'Overgrow']
# 2                    Ivysaur    Grass  Poison  ['Chlorophyll', 'Overgrow']
# 3                   Venusaur    Grass  Poison  ['Chlorophyll', 'Overgrow']
# 3              Mega Venusaur    Grass  Poison                ['Thick Fat']
# 4                 Charmander     Fire     NaN     ['Blaze', 'Solar Power']
# ...                      ...      ...     ...                          ...
# 896                Glastrier      Ice     NaN           ['Chilling Neigh']
# 897                Spectrier    Ghost     NaN               ['Grim Neigh']
# 898                  Calyrex  Psychic   Grass                  ['Unnerve']
# 898        Calyrex Ice Rider  Psychic     Ice                   ['As One']
# 898     Calyrex Shadow Rider  Psychic   Ghost                   ['As One']
#
# ...

# %%
datos_sin_nulos= datos_sin_dup.dropna().copy()
datos_sin_nulos
# Out:
#                                Name    Type 1  Type 2  \
# Number
# 1                         Bulbasaur     Grass  Poison
# 2                           Ivysaur     Grass  Poison
# 3                          Venusaur     Grass  Poison
# 3                     Mega Venusaur     Grass  Poison
# 6                         Charizard      Fire  Flying
# ...                             ...       ...     ...
# 892     Urshifu Single Strike Style  Fighting    Dark
# 893                          Zarude      Dark   Grass
# 898                         Calyrex   Psychic   Grass
# 898               Calyrex Ice Rider   Psychic     Ice
# 898            Calyrex Shadow Rider   Psychic   Ghost
#
#                           Abilities   HP  Att  Def  Spa  Spd  Spe  ...  \
# Number                                                             ...
# 1       ['Chlorophyll', 'Overgrow']   45   49   49   65   65   45  ...
# 2       ['Chlorophyll', 'Overgrow']   60   62   63   80   80   60  ...
# ...

# %%
def filtro_Fuego(Type):
    return 'Fire' in Type

datos_fuego = datos_sin_nulos[datos_sin_nulos['Type 1'].apply(filtro_Fuego)]

datos_fuego2= datos_sin_nulos[datos_sin_nulos['Type 2'].apply(filtro_Fuego)]

# %%
tipo_fuego= datos_fuego[["Name", "Type 1", "Type 2"]]
tipo_fuego2= datos_fuego2[["Name", "Type 1", "Type 2"]]
tipo_fuego+tipo_fuego2
# Out:
#                                             Name    Type 1            Type 2
# Number
# 6                             CharizardCharizard  FireFire      FlyingFlying
# 6               Mega Charizard YMega Charizard Y  FireFire      FlyingFlying
# 6               Mega Charizard XMega Charizard X  FireFire      DragonDragon
# 105                 Alolan MarowakAlolan Marowak  FireFire        GhostGhost
# 146                               MoltresMoltres  FireFire      FlyingFlying
# 219                             MagcargoMagcargo  FireFire          RockRock
# 250                                   Ho-OhHo-Oh  FireFire      FlyingFlying
# 256                           CombuskenCombusken  FireFire  FightingFighting
# 257                             BlazikenBlaziken  FireFire  FightingFighting
# 257                   Mega BlazikenMega Blaziken  FireFire  FightingFighting
# 322                                   NumelNumel  FireFire      GroundGround
# ...
